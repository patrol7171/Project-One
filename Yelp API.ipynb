# %%
import requests
import yelp.client41.9021667
from yelp.client import Client
from yelp.oauth1_authenticator import Oauth1Authenticator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1db5f2d90e6d> in <module>()
#       2 import yelp.client
#       3 from yelp.client import Client
# ----> 4 from yelp.oauth2_authenticator import Oauth1Authenticator
#
# ModuleNotFoundError: No module named 'yelp.oauth2_authenticator'

# %%
# !pip install yelp
# Out:
# ...
#   Running setup.py bdist_wheel for yelp: started
#   Running setup.py bdist_wheel for yelp: finished with status 'done'
#   Stored in directory: C:\Users\J\AppData\Local\pip\Cache\wheels\d3\1f\a5\0f0bb9c0d39a22643813579c9f00af832fea08c370c91e1efa
#   Running setup.py bdist_wheel for httplib2: started
#   Running setup.py bdist_wheel for httplib2: finished with status 'done'
#   Stored in directory: C:\Users\J\AppData\Local\pip\Cache\wheels\b2\79\b1\d8cd8ac7f345b464fb573b46fd1d523a7cd80ba0b778d2692c
# Successfully built yelp httplib2
# ...

# %%
client_id= 'M7mV67MJ1KtmqjorxVLbyA'
API_KEY= 'MorDAXlhkrcLM04Ek5Ya0vBT7A1rG4OZMGSb8Sqc6rE_AMcSF3pIq5Ed43YrWd6xsaQfi82g-MChCLNhh0Z-G7HrUUXkL7wd4kUesLg3quXFia-B5sBOJhHvAwfEWnYx'

# %%
a=requests.auth.HTTPBasicAuth(client_id, API_KEY)
headers = {"Authorization": "Bearer MorDAXlhkrcLM04Ek5Ya0vBT7A1rG4OZMGSb8Sqc6rE_AMcSF3pIq5Ed43YrWd6xsaQfi82g-MChCLNhh0Z-G7HrUUXkL7wd4kUesLg3quXFia-B5sBOJhHvAwfEWnYx"}

# %%
requests.get('https://api.yelp.com/v3/businesses/search?latitude=40.6892494&longitude=-74.04450039999999',headers=headers).json()
# Out:
# {'businesses': [{'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'}],
#    'coordinates': {'latitude': 40.70271971588, 'longitude': -74.0141777527019},
#    'display_phone': '(212) 363-3200',
#    'distance': 75.94992621409,
#    'id': 'statue-of-liberty-new-york-3',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tfSUDed87JksZKgnqLyLZw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1 Liberty Island',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['1 Liberty Island', 'New York, NY 10004'],
#     'state': 'NY',
#     'zip_code': '10004'},
#    'name': 'Statue of Liberty',
#    'phone': '+12123633200',
#    'rating': 4.5,
#    'review_count': 821,
#    'transactions': [],
# ...
